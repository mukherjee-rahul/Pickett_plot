# %%
from pickett import Pickett_plot
import pandas as pd
#turning on magic decorator for inline interactive plot in notebook
# %matplotlib widget

# %%
# Importing data
data = pd.read_csv('sample_data.csv')
print(data.columns)
# Out:
# Index(['DEPTH', 'Rt', 'PHIT'], dtype='object')

# %%
# Plotting phit > 10% only
Pickett_plot(data[data['PHIT']>0.1]['Rt'], data[data['PHIT']>0.1]['PHIT'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
